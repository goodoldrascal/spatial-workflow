# %% [markdown]
# # 01 · Prepare AnnData
#
# Edit `configs/local.yaml`, then use this notebook to generate the conversion job. The notebook writes a shell script but does not run it.

# %%
import sys
from pathlib import Path

REPO_ROOT = Path.cwd().resolve()
if REPO_ROOT.name == "notebooks":
    REPO_ROOT = REPO_ROOT.parent
SOURCE_ROOT = str(REPO_ROOT / "src")
if SOURCE_ROOT not in sys.path:
    sys.path.insert(0, SOURCE_ROOT)

from spatial_workflow.config import load_config
from spatial_workflow.launchers import write_conversion_script

CONFIG_PATH = REPO_ROOT / "configs" / "local.yaml"
SCRIPT_PATH = REPO_ROOT / "jobs" / "01_prepare_anndata.sh"

config = load_config(CONFIG_PATH)
config["conversion"]

# %% [markdown]
# Generate and inspect the job before copying or running it in the configured environment.

# %%
script_path = write_conversion_script(CONFIG_PATH, SCRIPT_PATH)
print(script_path.read_text())
print(f"Run manually when ready: bash {script_path}")
